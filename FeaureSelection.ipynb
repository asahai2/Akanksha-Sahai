# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("overmedication.csv")
df.head()
# Out:
#    HospitalAdmissions  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0                   6      148             72             35        0  33.6
# 1                   1       85             66             29        0  26.6
# 2                   8      183             64              0        0  23.3
# 3                   1       89             66             23       94  28.1
# 4                   0      137             40             35      168  43.1
#
#    DosageOfCurrentMedication  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 2                      0.672   32        1
# 3                      0.167   21        0
# 4                      2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['HospitalAdmissions', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'Insulin', 'BMI', 'DosageOfCurrentMedication', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# HospitalAdmissions           768 non-null int64
# Glucose                      768 non-null int64
# BloodPressure                768 non-null int64
# SkinThickness                768 non-null int64
# Insulin                      768 non-null int64
# BMI                          768 non-null float64
# DosageOfCurrentMedication    768 non-null float64
# Age                          768 non-null int64
# Outcome                      768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        HospitalAdmissions     Glucose  BloodPressure  SkinThickness  \
# count          768.000000  768.000000     768.000000     768.000000
# mean             3.845052  120.894531      69.105469      20.536458
# std              3.369578   31.972618      19.355807      15.952218
# min              0.000000    0.000000       0.000000       0.000000
# 25%              1.000000   99.000000      62.000000       0.000000
# 50%              3.000000  117.000000      72.000000      23.000000
# 75%              6.000000  140.250000      80.000000      32.000000
# max             17.000000  199.000000     122.000000      99.000000
#
#           Insulin         BMI  DosageOfCurrentMedication         Age  \
# count  768.000000  768.000000                 768.000000  768.000000
# mean    79.799479   31.992578                   0.471876   33.240885
# std    115.244002    7.884160                   0.331329   11.760232
# min      0.000000    0.000000                   0.078000   21.000000
# 25%      0.000000   27.300000                   0.243750   24.000000
# 50%     30.500000   32.000000                   0.372500   29.000000
# 75%    127.250000   36.600000                   0.626250   41.000000
# max    846.000000   67.100000                   2.420000   81.000000
#
#           Outcome
# count  768.000000
# mean     0.348958
# std      0.476951
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
df.isnull().sum()
# Out:
# HospitalAdmissions           0
# Glucose                      0
# BloodPressure                0
# SkinThickness                0
# Insulin                      0
# BMI                          0
# DosageOfCurrentMedication    0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
df.corr()
# Out:
#                            HospitalAdmissions   Glucose  BloodPressure  \
# HospitalAdmissions                   1.000000  0.129459       0.141282
# Glucose                              0.129459  1.000000       0.152590
# BloodPressure                        0.141282  0.152590       1.000000
# SkinThickness                       -0.081672  0.057328       0.207371
# Insulin                             -0.073535  0.331357       0.088933
# BMI                                  0.017683  0.221071       0.281805
# DosageOfCurrentMedication           -0.033523  0.137337       0.041265
# Age                                  0.544341  0.263514       0.239528
# Outcome                              0.221898  0.466581       0.065068
#
#                            SkinThickness   Insulin       BMI  \
# HospitalAdmissions             -0.081672 -0.073535  0.017683
# Glucose                         0.057328  0.331357  0.221071
# BloodPressure                   0.207371  0.088933  0.281805
# SkinThickness                   1.000000  0.436783  0.392573
# Insulin                         0.436783  1.000000  0.197859
# BMI                             0.392573  0.197859  1.000000
# DosageOfCurrentMedication       0.183928  0.185071  0.140647
# Age                            -0.113970 -0.042163  0.036242
# Outcome                         0.074752  0.130548  0.292695
#
#                            DosageOfCurrentMedication       Age   Outcome
# HospitalAdmissions                         -0.033523  0.544341  0.221898
# Glucose                                     0.137337  0.263514  0.466581
# BloodPressure                               0.041265  0.239528  0.065068
# SkinThickness                               0.183928 -0.113970  0.074752
# Insulin                                     0.185071 -0.042163  0.130548
# BMI                                         0.140647  0.036242  0.292695
# DosageOfCurrentMedication                   1.000000  0.033561  0.173844
# Age                                         0.033561  1.000000  0.238356
# Outcome                                     0.173844  0.238356  1.000000

# %%
X = df.iloc[:,0:8] 
y = df.iloc[:,-1]   
bestfeatures = SelectKBest(score_func=chi2, k=8)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns) 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']  
print(featureScores.nlargest(8,'Score'))
# Out:
#                     Features        Score
# 4                    Insulin  2175.565273
# 1                    Glucose  1411.887041
# 7                        Age   181.303689
# 5                        BMI   127.669343
# 0         HospitalAdmissions   111.519691
# 3              SkinThickness    53.108040
# 2              BloodPressure    17.605373
# 6  DosageOfCurrentMedication     5.392682
